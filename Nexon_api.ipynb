# %%
import pandas as pd
# %pip install --upgrade requests
import requests
import random
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 넥슨 오픈 API 키
headers = {
  "x-nxopen-api-key": "live_eb781e7377372ceece616617e8096039cea8b4af1c1782cab4bb12ca9073e6ccefe8d04e6d233bd35cf2fabdeb93fb0d"
}

# %%
# 캐릭터의 정보를 가져오는 함수
# 캐릭터의 정보를 가져올 때, date가 2024-01-01인 데이터만 읽어서 최적화합니다.

def get_character_info(headers, ocid, date):
    params = {"date":"2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/basic?ocid="+ocid, headers = headers, params = params)
    return response.json()


# 캐릭터의 OCID를 가져오는 함수
def get_ocid(headers, name):    
    params = {"character_name":name}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/id", headers = headers, params = params)
    return response.json()

# 인기도 정보를 가져오는 함수
def get_popularity(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/popularity?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 종합 능력치 정보를 가져오는 함수
def get_stat(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/stat?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 하이퍼 스텟 정보를 가져오는 함수
def get_hyper_stat(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/hyper-stat?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 성향 정보를 가져오는 함수
def get_personality(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/propensity?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 어빌리티 정보를 가져오는 함수
def get_ability(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/ability?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 장비 정보를 가져오는 함수
def get_equipment(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/item-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 캐시 장비 정보를 가져오는 함수
def get_cash_equipment(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/cashitem-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 심볼 정보를 가져오는 함수
def get_symbol(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/symbol-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 적용 세트 효과 정보를 가져오는 함수
def get_set_effect(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/set-effect?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 헤어, 성형, 피부 정보를 가져오는 함수
def get_face_hair_skin(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/beauty-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 안드로이드 정보를 가져오는 함수
def get_android(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/android-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 펫 정보를 가져오는 함수
def get_pet(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/pet-equipment?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 장착 링크 스킬 정보를 가져오는 함수
def get_link_skill(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/link-skill?ocid="+ocid, headers=headers, params=params)
    return response.json()

# V매트릭스 정보를 가져오는 함수
def get_v_matrix(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/vmatrix?ocid="+ocid, headers=headers, params=params)
    return response.json()

# HEXA코어 정보를 가져오는 함수
def get_hexa_core(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/hexamatrix?ocid="+ocid, headers=headers, params=params)
    return response.json()

# HEXA 매트릭스 설정 HEXA 스탯 정보 조회
def get_hexa_stat(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/hexamatrix-stat?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 무릉도장 최고 기록 정보를 가져오는 함수
def get_dojang(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/character/dojang?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 유니온 정보를 가져오는 함수
def get_union(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/user/union?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 유니온 공격대 정보를 가져오는 함수
def get_union_raider(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/user/union-raider?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 유니온 아티팩트 정보를 가져오는 함수
def get_union_artifact(headers, ocid):
    params = {"date": "2024-12-15"}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/user/union-artifact?ocid="+ocid, headers=headers, params=params)
    return response.json()

# 랭킹 정보를 가져오는 함수
def get_name(headers, today, i, weight):
    params = {"date": today, "page": i}
    response = requests.get("https://open.api.nexon.com/maplestory/v1/ranking/overall", headers=headers, params=params)
    return response.json()

# %%
# 랭킹을 가져오는 코드
ranking = []
for i in range(1, 60000+1):
    result = get_name(headers,"2024-12-27", i, 200)
    ranking.append(result)
ranking

# %%
# ocid를 가져오는 코드
# ranking의 character_name을 가져와서 ocid를 가져옴
ocid = []
for i in range(0, 1):
    for j in range(0, 60000+1):
        ocid.append(get_ocid(headers, ranking[i]['ranking'][j]['character_name']))
ocid
# Out:
# [{'ranking': [{'date': '2024-12-27',
#     'world_name': '루나',
#     'ranking': 1,
#     'character_name': '오지환',
#     'character_level': 299,
#     'character_exp': 855408331451862,
#     'class_name': '프렌즈 월드',
#     'sub_class_name': '키네시스',
#     'character_popularity': 28827,
#     'character_guildname': '루나'},
#    {'date': '2024-12-27',
#     'world_name': '엘리시움',
#     'ranking': 2,
#     'character_name': '버터',
#     'character_level': 299,
#     'character_exp': 423873395419024,
#     'class_name': '도적',
#     'sub_class_name': '나이트로드',
#     'character_popularity': 410,
#     'character_guildname': None},
#    {'date': '2024-12-27',
#     'world_name': '이노시스',
#     'ranking': 3,
#     'character_name': '테룽이',
#     'character_level': 298,
#     'character_exp': 620380104109675,
#     'class_name': '카이저',
#     'sub_class_name': '',
#     'character_popularity': 1126,
#     'character_guildname': '프라하'},
#    {'date': '2024-12-27',
#     'world_name': '크로아',
# ...

# %% [markdown]
# # 캐릭터 정보를 가져오는 코드
# # ocid를 가져와서 캐릭터 정보를 가져옴
# # output에 ocid를 추가
# character_info = []
# for i in range(0, 60000+1):
#     info = get_character_info(headers, ocid[i]['ocid'], "2024-12-27")
#     info['ocid'] = ocid[i]['ocid']
#     character_info.append(info)
# character_info
